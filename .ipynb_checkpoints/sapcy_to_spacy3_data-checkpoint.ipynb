# %%
import spacy

print(spacy.__version__)
# Out:
# 3.0.2

# %%
import pandas as pd
from tqdm import tqdm
import pickle
from spacy.tokens import DocBin

# %%
with open ('asdf', 'rb') as fp:
    TRAIN_DATA = pickle.load(fp)
    
nlp = spacy.blank('en')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-00cc753b71ac> in <module>
#       2     TRAIN_DATA = pickle.load(fp)
#       3
# ----> 4 nlp = spacy.blank('en')
#
# ~/.local/lib/python3.8/site-packages/spacy/__init__.py in blank(name, vocab, config, meta)
#      66     # We should accept both dot notation and nested dict here for consistency
#      67     config = util.dot_to_dict(config)
# ---> 68     return LangClass.from_config(config, vocab=vocab, meta=meta)
#
# ~/.local/lib/python3.8/site-packages/spacy/language.py in from_config(cls, config, vocab, disable, exclude, meta, auto_fill, validate)
#    1620         # then we would load them twice at runtime: once when we make from config,
#    1621         # and then again when we load from disk.
# -> 1622         nlp = lang_cls(vocab=vocab, create_tokenizer=create_tokenizer, meta=meta)
#    1623         if after_creation is not None:
#    1624             nlp = after_creation(nlp)
#
# ~/.local/lib/python3.8/site-packages/spacy/language.py in __init__(self, vocab, max_length, meta, create_tokenizer, batch_size, **kwargs)
#     147         # points. The factory decorator applied to these functions takes care
#     148         # of the rest.
# --> 149         util.registry._entry_point_factories.get_all()
#     150
#     151         self._config = DEFAULT_CONFIG.merge(self.default_config)
#
# ~/.local/lib/python3.8/site-packages/catalogue/__init__.py in get_all(self)
#     106         result = {}
#     107         if self.entry_points:
# --> 108             result.update(self.get_entry_points())
#     109         for keys, value in REGISTRY.items():
#     110             if len(self.namespace) == len(keys) - 1 and all(
#
# ~/.local/lib/python3.8/site-packages/catalogue/__init__.py in get_entry_points(self)
#     121         result = {}
#     122         for entry_point in AVAILABLE_ENTRY_POINTS.get(self.entry_point_namespace, []):
# --> 123             result[entry_point.name] = entry_point.load()
#     124         return result
#     125
#
# /usr/lib/python3.8/importlib/metadata.py in load(self)
#      75         """
#      76         match = self.pattern.match(self.value)
# ---> 77         module = import_module(match.group('module'))
#      78         attrs = filter(None, (match.group('attr') or '').split('.'))
#      79         return functools.reduce(getattr, attrs, module)
#
# /usr/lib/python3.8/importlib/__init__.py in import_module(name, package)
#     125                 break
#     126             level += 1
# --> 127     return _bootstrap._gcd_import(name[level:], package, level)
#     128
#     129
#
# /usr/lib/python3.8/importlib/_bootstrap.py in _gcd_import(name, package, level)
#
# /usr/lib/python3.8/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# /usr/lib/python3.8/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# /usr/lib/python3.8/importlib/_bootstrap.py in _load_unlocked(spec)
#
# /usr/lib/python3.8/importlib/_bootstrap_external.py in exec_module(self, module)
#
# /usr/lib/python3.8/importlib/_bootstrap.py in _call_with_frames_removed(f, *args, **kwds)
#
# ~/.local/lib/python3.8/site-packages/spacy_transformers/__init__.py in <module>
# ----> 1 from .language import TransformersLanguage
#       2 from .pipeline.tok2vec import TransformersTok2Vec  # noqa
#       3 from .pipeline.textcat import TransformersTextCategorizer  # noqa
#       4 from .pipeline.wordpiecer import TransformersWordPiecer  # noqa
#       5 from .model_registry import register_model, get_model_function  # noqa
#
# ~/.local/lib/python3.8/site-packages/spacy_transformers/language.py in <module>
#       2 from spacy.tokens import Doc, Span, Token
#       3 from spacy.util import get_lang_class
# ----> 4 from spacy.gold import GoldParse
#       5 from .util import is_special_token, pkg_meta, ATTRS, PIPES, LANG_FACTORY
#       6
#
# ModuleNotFoundError: No module named 'spacy.gold'

# %%
nlp = spacy.blank('en') # load a new spacy model
db = DocBin() # create a DocBin object

for text, annot in tqdm(TRAIN_DATA): # data in previous format
    doc = nlp.make_doc(text) # create doc object from text
    ents = []
    for start, end, label in annot["entities"]: # add character indexes
        span = doc.char_span(start, end, label=label, alignment_mode="contract")
        if span is None:
            print("Skipping entity")
        else:
            ents.append(span)
    doc.ents = ents # label the text with the ents
    db.add(doc)

db.to_disk("./traint.spacy") # save the docbin object
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-4657234485a1> in <module>
# ----> 1 nlp = spacy.blank('en') # load a new spacy model
#       2 db = DocBin() # create a DocBin object
#       3
#       4 for text, annot in tqdm(TRAIN_DATA): # data in previous format
#       5     doc = nlp.make_doc(text) # create doc object from text
#
# ~/.local/lib/python3.8/site-packages/spacy/__init__.py in blank(name, vocab, config, meta)
#      66     # We should accept both dot notation and nested dict here for consistency
#      67     config = util.dot_to_dict(config)
# ---> 68     return LangClass.from_config(config, vocab=vocab, meta=meta)
#
# ~/.local/lib/python3.8/site-packages/spacy/language.py in from_config(cls, config, vocab, disable, exclude, meta, auto_fill, validate)
#    1632         # then we would load them twice at runtime: once when we make from config,
#    1633         # and then again when we load from disk.
# -> 1634         nlp = lang_cls(vocab=vocab, create_tokenizer=create_tokenizer, meta=meta)
#    1635         if after_creation is not None:
#    1636             nlp = after_creation(nlp)
#
# ~/.local/lib/python3.8/site-packages/spacy/language.py in __init__(self, vocab, max_length, meta, create_tokenizer, batch_size, **kwargs)
#     148         # points. The factory decorator applied to these functions takes care
#     149         # of the rest.
# --> 150         util.registry._entry_point_factories.get_all()
#     151
#     152         self._config = DEFAULT_CONFIG.merge(self.default_config)
#
# ~/.local/lib/python3.8/site-packages/catalogue/__init__.py in get_all(self)
#     106         result = {}
#     107         if self.entry_points:
# --> 108             result.update(self.get_entry_points())
#     109         for keys, value in REGISTRY.items():
#     110             if len(self.namespace) == len(keys) - 1 and all(
#
# ~/.local/lib/python3.8/site-packages/catalogue/__init__.py in get_entry_points(self)
#     121         result = {}
#     122         for entry_point in AVAILABLE_ENTRY_POINTS.get(self.entry_point_namespace, []):
# --> 123             result[entry_point.name] = entry_point.load()
#     124         return result
#     125
#
# /usr/lib/python3.8/importlib/metadata.py in load(self)
#      75         """
#      76         match = self.pattern.match(self.value)
# ---> 77         module = import_module(match.group('module'))
#      78         attrs = filter(None, (match.group('attr') or '').split('.'))
#      79         return functools.reduce(getattr, attrs, module)
#
# /usr/lib/python3.8/importlib/__init__.py in import_module(name, package)
#     125                 break
#     126             level += 1
# --> 127     return _bootstrap._gcd_import(name[level:], package, level)
#     128
#     129
#
# /usr/lib/python3.8/importlib/_bootstrap.py in _gcd_import(name, package, level)
#
# /usr/lib/python3.8/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# /usr/lib/python3.8/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# /usr/lib/python3.8/importlib/_bootstrap.py in _load_unlocked(spec)
#
# /usr/lib/python3.8/importlib/_bootstrap_external.py in exec_module(self, module)
#
# /usr/lib/python3.8/importlib/_bootstrap.py in _call_with_frames_removed(f, *args, **kwds)
#
# ~/.local/lib/python3.8/site-packages/spacy_transformers/__init__.py in <module>
# ----> 1 from .language import TransformersLanguage
#       2 from .pipeline.tok2vec import TransformersTok2Vec  # noqa
#       3 from .pipeline.textcat import TransformersTextCategorizer  # noqa
#       4 from .pipeline.wordpiecer import TransformersWordPiecer  # noqa
#       5 from .model_registry import register_model, get_model_function  # noqa
#
# ~/.local/lib/python3.8/site-packages/spacy_transformers/language.py in <module>
#       2 from spacy.tokens import Doc, Span, Token
#       3 from spacy.util import get_lang_class
# ----> 4 from spacy.gold import GoldParse
#       5 from .util import is_special_token, pkg_meta, ATTRS, PIPES, LANG_FACTORY
#       6
#
# ModuleNotFoundError: No module named 'spacy.gold'
